# %% [markdown]
# DESCRIPTION
# STEP	ACTION
# 1	User Action: Customer logs into the app.
# 2	User Action: Customer browses the menu and selects products.
# 3	User Action: Customer customizes the order (e.g., messages on pastries).
# 4	User Action: Customer selects delivery or pickup and enters address if needed.
# 5	User Action: Customer selects payment method (e.g., GCash) and confirms.
# 6	System Action: System processes payment and sends confirmation.
# 7	System Action: System sends order details to the kitchen and updates the order status.
# 8	System Action: Sends notifications for each order status (e.g., “Being Prepared”, “Out for Delivery”).
#
# STEP EXTENSIONS
# STEP	BRANCHES
# 5.a Payment Failed	Branch from Step 5: System shows error message and asks user to retry or select a different method.
# 7.a Kitchen Delay	Branch from Step 7: System notifies customer of expected delay.
#
# ALTERNATE COURSES
# STEP	ACTION
# A1	User Action: Customer cancels order before payment.
# A2	System Action: System stops the order process and returns to cart.
# A3	User Action: Customer modifies cart and restarts order process.
#
# 🖼 B. Use Case Diagram
# We will include the following in the diagram:
#
# Actors:
#
# Customer
#
# System
#
# Kitchen Staff
#
# Delivery Rider
#
# Use Cases:
#
# Log in
#
# Browse Menu
#
# Customize Order
#
# Select Delivery Option
#
# Make Payment
#
# Track Order
#
# Receive Order Updates
#
# Cancel Order (Alternative Flow)
